# %% [markdown]
# # ASSIGNMENT BY VINAY KUMAR KUSHWAHA (FE-2147)

# %%
##Importing all python libaries....
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # # Question 1
# # # Q1.Create a list with five stocks of your own choice which are being traded on NSE and perform operations studied in class on them.

# %%
stocks = ['HUL','ONGC','Cipla','SAIL','Wipro']
print(stocks)
# Out:
# ['HUL', 'ONGC', 'Cipla', 'SAIL', 'Wipro']

# %%
stocks1 = stocks [1:3]
print(stocks1)
# Out:
# ['ONGC', 'Cipla']

# %%
stocks.append('Reliance')
print(stocks)
# Out:
# ['HUL', 'ONGC', 'Cipla', 'SAIL', 'Wipro', 'Reliance']

# %%
stocks.pop(2)
print(stocks)
# Out:
# ['HUL', 'ONGC', 'SAIL', 'Wipro', 'Reliance']

# %%
stocks2=["HCL", 'SBIN']
stocks.extend(stocks2)
print(stocks)
# Out:
# ['HUL', 'ONGC', 'SAIL', 'Wipro', 'Reliance', 'HCL', 'SBIN']

# %%
stocks[3]= "TCS"
print(stocks)
# Out:
# ['HUL', 'ONGC', 'SAIL', 'TCS', 'Reliance', 'HCL', 'SBIN']

# %%
length_x= len(stocks)
print(length_x)
# Out:
# 7

# %% [markdown]
# # # Question 2..
# # # Q2.Create a tupple with five stock prices of your own choice which are being traded on NSE and perform operations studied in class on them.

# %%
tuple_st = ('HUL','ONGC','Cipla','SAIL','Wipro')
print(tuple_st)
# Out:
# ('HUL', 'ONGC', 'Cipla', 'SAIL', 'Wipro')

# %%
tuple_st[1:3]
# Out:
# ('ONGC', 'Cipla')

# %%
print(tuple_st.index('Cipla'))
# Out:
# 2

# %%
tuple_no = (4,5,6)
print(tuple_no)
# Out:
# (4, 5, 6)

# %%
ty = tuple_no + tuple_st
print(ty)
# Out:
# (4, 5, 6, 'HUL', 'ONGC', 'Cipla', 'SAIL', 'Wipro')

# %% [markdown]
# # # Question 3...
# # # Q3.Define a data frame using Pandas , for number of contracts( OR lots in case of stocks ) for options or futures or stocks being  traded on NSE each day in last week  with its volume  turnover on respective dates. Now ,define another data frame using Pandas , for number of contracts( OR lots in case of stocks ) for options or futures or stocks being  traded on NSE each day in last week  with risk free rate( LIBOR, MIBOR or 91 day TBill rate) on respective dates. And now perform merging , joining concatenation on these data frames.Also specify when is joining and merging possible.

# %%
import pandas as pd
niftyf_volumes = {"date": ["10-Mar-2022", "11-Mar-2022" , "14-Mar-2022","15-Mar-2022", "16-Mar-2022"],
                         "niftyf_vol_turnover" : ["2660305", "1797833","1733802","2308501","2020187"]}
df_x = pd.DataFrame(niftyf_volumes)
print(df_x)
# Out:
#           date niftyf_vol_turnover
# 0  10-Mar-2022             2660305
# 1  11-Mar-2022             1797833
# 2  14-Mar-2022             1733802
# 3  15-Mar-2022             2308501
# 4  16-Mar-2022             2020187

# %%
niftyf_MIBOR = {"date": ["10-Mar-2022", "11-Mar-2022" , "14-Mar-2022","15-Mar-2022", "16-Mar-2022"],
                         "MIBOR_vol" : ["12018700", "12444150","13002400","12705150","11289150"]}
df_y = pd.DataFrame(niftyf_MIBOR)
print(df_y)
# Out:
#           date MIBOR_vol
# 0  10-Mar-2022  12018700
# 1  11-Mar-2022  12444150
# 2  14-Mar-2022  13002400
# 3  15-Mar-2022  12705150
# 4  16-Mar-2022  11289150

# %%
merge=pd.merge(df_x,df_y)

print(merge)
# Out:
#           date niftyf_vol_turnover MIBOR_vol
# 0  10-Mar-2022             2660305  12018700
# 1  11-Mar-2022             1797833  12444150
# 2  14-Mar-2022             1733802  13002400
# 3  15-Mar-2022             2308501  12705150
# 4  16-Mar-2022             2020187  11289150

# %%
Concat=pd.concat([df_x,df_y])
print(Concat)
# Out:
#           date niftyf_vol_turnover MIBOR_vol
# 0  10-Mar-2022             2660305       NaN
# 1  11-Mar-2022             1797833       NaN
# 2  14-Mar-2022             1733802       NaN
# 3  15-Mar-2022             2308501       NaN
# 4  16-Mar-2022             2020187       NaN
# 0  10-Mar-2022                 NaN  12018700
# 1  11-Mar-2022                 NaN  12444150
# 2  14-Mar-2022                 NaN  13002400
# 3  15-Mar-2022                 NaN  12705150
# 4  16-Mar-2022                 NaN  11289150

# %% [markdown]
# # # Question 4...
# # # Q4. Create a 2 X 3  array of elements of your choice using ‘Numpy’   and perform the following.....
# # ## (A) Find data dimension and data type
# # ## (B) Determine shape of array
# # ## (C) Try to reshape and slicing the array using Index positions [0,1], [0:,2],[0:,[0,3]
# # ## (D) Perform horizontal stacking and vertical stacking  of array.
# # ## (E) Consider summing the array along its both axis.

# %%
#Find data dimension and data type
import numpy as np
az =np.array([(8,1,5),(6,3,1)])
print(az.ndim)
print(az.size)
print(az.dtype)
# Out:
# 2
# 6
# int32

# %%
#Determine shape of array
print(az.shape)
# Out:
# (2, 3)

# %%
#Try to reshape and slicing the array using Index positions [0,1], [0:,2],[0:,], [0,3]
print(az.reshape(3,2))
# Out:
# [[8 1]
#  [5 6]
#  [3 1]]

# %%
print(az[0,1])
# Out:
# 1

# %%
print(az[0:,2])
# Out:
# [5 1]

# %%
print(az[0:,])
# Out:
# [[8 1 5]
#  [6 3 1]]

# %%
#because array using Index positions [0,3] shown error due to index 3 is out of bounds for axis 1 with size 3
print(az[0:1,2])
# Out:
# [5]

# %%
#Perform horizontal stacking and vertical stacking  of array.
az=np.array([(8,1,5),(6,3,1)])
ak=np.array([(1,2,3),(3,4,5)])

# %%
print(np.vstack((az,ak)))
# Out:
# [[8 1 5]
#  [6 3 1]
#  [1 2 3]
#  [3 4 5]]

# %%
print(np.hstack((az,ak)))
# Out:
# [[8 1 5 1 2 3]
#  [6 3 1 3 4 5]]

# %%
#Consider summing the array along its both axis.
az =np.array([(8,1,5),(6,3,1)])

print(az.sum(axis=0))

print(az.sum(axis=1))
# Out:
# [14  4  6]
# [14 10]

# %% [markdown]
# # Question 5..
# # # Q5.Try to plot a bar plot, histogram , for last traded stock prices of last six days of Reliance (Data available on NSE website)

# %%
import pandas as pd
import matplotlib.pyplot as plt
#importing reliance equity historial data(9-march to 16 march)

rel = pd.read_csv(r"C:\Users\HP\Downloads\RELIANCE-EQ.csv")
rel
# Out:
#        Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0  09-Mar-22      EQ  2,236.00  2,367.00  2,234.15     2,235.50  2,358.30
# 1  10-Mar-22      EQ  2,400.00  2,405.00  2,360.00     2,354.10  2,387.00
# 2  11-Mar-22      EQ  2,376.05  2,411.00  2,376.05     2,392.25  2,393.15
# 3  14-Mar-22      EQ  2,386.90  2,424.40  2,374.00     2,399.15  2,422.20
# 4  15-Mar-22      EQ  2,427.95  2,427.95  2,340.85     2,418.85  2,362.00
# 5  16-Mar-22      EQ  2,382.00  2,407.90  2,377.10     2,363.45  2,401.50
#
#      close      vwap     52W H     52W L   VOLUME               VALUE   \
# 0  2,354.10  2,316.35  2,751.35  1,876.70  9421163  21,82,27,06,477.90
# 1  2,392.25  2,386.79  2,751.35  1,876.70  8297995  19,80,55,99,252.70
# 2  2,399.15  2,396.11  2,751.35  1,876.70  5656799  13,55,42,90,818.70
# 3  2,418.85  2,401.52  2,751.35  1,876.70  3849222   9,24,39,98,854.25
# 4  2,363.45  2,386.09  2,751.35  1,876.70  7349740  17,53,71,36,611.95
# ...

# %%
#converting into dataframe

df = pd.DataFrame(rel)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 7])

print(X)

print(Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/1446799975.py in <module>
#       1 #converting into dataframe
#       2
# ----> 3 df = pd.DataFrame(rel)
#       4
#       5 X = list(df.iloc[:, 0])
#
# NameError: name 'pd' is not defined

# %%
Date = ["9-Mar-22", "10-Mar-22", "11-Mar-22","14-Mar-22","15-Mar-22","16-Mar-22"]
closing_price = [2354.10, 2392.25, 2399.15, 2418.85, 2363.45, 2403.35]

#plotting the bar for last 6 days (9-16 march 2022)
plt.figure(figsize=(10,8))
plt.title("Reliance Stock Price over last week")
plt.xlabel("Date")
plt.ylabel("Closing stock price")
plt.bar(Date, closing_price ,edgecolor="black", color= "red")
plt.show()

# %%
#plotting the histogram for last 6 days (9-16 march 2022) 

closing_price = np.array ([2354.10, 2392.25, 2399.15, 2418.85, 2363.45, 2403.35])
plt.figure(figsize=(10,8))
plt.hist (closing_price,bins=[2200,2250,2300,2350,2400,2450,2500],edgecolor='black', color= "orange")
plt.title("Histogram of Reliance Stock Price for last 6 days (9-16 march 2022)")
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # # Question 6...
# # # Q6.Try to plot a  pie chart for top 5 equities  in NIFTY 50  list  available on https://www.nseindia.com/market-data/live-equity-market based on proportion of volume of  each stock in the total volume of NIFTY 50

# %%
import pandas as pd
import matplotlib.pyplot as plt

#importing csv file of nifty 50 

nifty_vol = pd.read_csv(r"C:\Users\HP\Downloads\MW-NIFTY-50-17-Mar-2022.csv")

nifty_vol
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  16,876.65  16,987.90  16,837.85      16,663.00  16,975.35
# 1   TATAMOTORS     427.05     428.55      420.7         413.65        424
# 2         ONGC        166     167.85     161.85         163.75      167.2
# 3          ITC        240        243      239.1         237.85      242.4
# 4         SBIN        493      494.3      489.4         485.85     491.95
# 5    ICICIBANK      706.9      711.4     701.25         697.35      706.6
# 6    COALINDIA        173      177.8      172.9          172.9      176.3
# 7     HINDALCO      568.7      575.4      563.3         559.75      574.4
# 8          IOC      120.3      122.6     119.45            119      121.8
# 9     AXISBANK        711        726      709.1         698.15     722.95
# 10   POWERGRID     211.25      211.8     208.95         209.65     209.95
# 11    HDFCBANK   1,447.00   1,455.00   1,436.20       1,424.00   1,445.95
# ...

# %%
#top 5 equities and their volumes on 17 march from nifty 50..

total_top5= nifty_vol[["SYMBOL \n","VOLUME(shares)"]].iloc[1:6]
total_top5
# Out:
#     SYMBOL \n  VOLUME(shares)
# 1  TATAMOTORS        27191170
# 2        ONGC        25545119
# 3         ITC        21629521
# 4        SBIN        16211288
# 5   ICICIBANK        14621688

# %%
#plotting Pie chart on proportion of volume of top 5 equities in the total volume of NIFTY 50

top_5_stocks = ["TATAMOTORS","ONGC","ITC","SBIN","ICICIBANK"]
volume_shares = np.array([27191170,25545119,21629521,16211288,14621688])

plt.figure(figsize=(14,10))
plt.pie(volume_shares, labels = top_5_stocks,startangle=90,shadow=True,autopct='%1.2f%%')
plt.title("Pie chart on proportion of volume of top 5 equities in the total volume of NIFTY 50 ")
plt.legend(top_5_stocks,loc='best')
plt.show()
